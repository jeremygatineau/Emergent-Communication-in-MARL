# %%
import numpy as np
import matplotlib.pyplot as plt

from oneDtoyTask import ToyTask, OneDfield, TwoWayComChannel

# %%
field = OneDfield(speed=10)
Task = ToyTask(field=field, observationMappingFct=lambda x: (x>0.5).astype(int), comChannel=TwoWayComChannel())

# %%
np.random.seed(1)
field = OneDfield(speed=10)
Task = ToyTask(field=field, observationMappingFct=lambda x: (x>0.5).astype(int), comChannel=TwoWayComChannel())

Task.step(predictions=(1, 0), messages=("yo", "wassap"))
fig, axs = Task.render()
plt.show()
# Out:
# 7

# %%
Task.hiddenStateField.speed = 2
Task.step(predictions=(1, 0), messages=("yo", "wassap"))
fig, axs = Task.render()
plt.show()
