# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from oneDtoyTask.oneDtoyTask import ToyTask, OneDfield, TwoWayComChannel
from agents.agent_AriaRE import AriaRE
from agents.agent_AriaOnlineAC import AriaOnlineAC
from IPython import display

# %%
epochs = 1000
opt_params = {"lr":0.0005, "batch_size":10, "gamma":0.999}
agent0 = AriaOnlineAC(opt_params=opt_params, with_memory=True).float()
agent1 = AriaOnlineAC(opt_params=opt_params).float()
np.random.seed(1)
field = OneDfield(speed=2)
Task = ToyTask(field=field, observationMappingFct=lambda x: (x>0.5).astype(int), comChannel=TwoWayComChannel())

# %%
def plot_preds(obsers, preds):
    display.clear_output(wait=True)
    plt.clf()
    obsers = np.array(obsers)
    preds = np.array(preds)
    
    fig, axs = plt.subplots(1, 2, figsize=(16, 6))
    axs[0].plot(obsers[:, 0])
    axs[0].plot(preds[:, 0])
    axs[0].legend(['observations', 'predictions'])
    axs[0].set_title('Agent 0')
    axs[0].set_xlabel('Epoch')

    axs[1].plot(obsers[:, 1])
    axs[1].plot(preds[:, 1])
    axs[1].legend(['observations', 'predictions'])
    axs[1].set_title('Agent 1')
    axs[1].set_xlabel('Epoch')
    plt.grid(True)
    
    display.display(plt.gcf())
    return fig

# %%
obs, downlink_msgs = Task.reset()
losses = []
rewards1 = []
rewards2 = []
torch.autograd.set_detect_anomaly(True)
epoch = 0
observations = []
predictions = []
while epoch<epochs:
    
    a0, m0u =  agent0.select_action(obs[0], downlink_msgs[0])
    a1, m1u = agent1.select_action(obs[1], downlink_msgs[1])
    m0u_ = np.zeros(4)
    m1u_ = np.zeros(4)
    m0u_[m0u.item()] = 1
    m1u_[m1u.item()] = 1
    observations.append([obs[0][1], obs[1][0]])
    predictions.append((a0.item(), a1.item()))
    (obs_, downlink_msgs_), r, done = Task.step([a0.item(), a1.item()], [m0u_, m1u_])
    loss0, rew1 = agent0.train_on_batch([obs[0], downlink_msgs[0]], r[0], [obs_[0], downlink_msgs_[0]])
    loss1, rew2 = agent1.train_on_batch([obs[1], downlink_msgs[1]], r[1], [obs_[1], downlink_msgs_[1]])
    obs = obs_
    downlink_msgs = downlink_msgs_
        
    if loss0 is not None:
        
        if epoch%10==0:
            fig  = plot_preds(observations, predictions)
            observations = []
            predictions = []
            print(f"epoch {epoch}/{epochs} loss, reward:  agent 0 {loss0}, {np.mean(rew1)} loss agent 1 {loss1}, {np.mean(rew2)}")

        losses.append([loss0, loss1])
        rewards1.append(rew1)
        rewards1.append(rew2)
        epoch+=1
        plt.close()
# Out:
# epoch 910/1000 loss, reward:  agent 0 (0.9491803050041199, 0.9704813957214355), 1.0 loss agent 1 (1.2908295392990112, 0.9982939958572388), 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d0dc737978b1> in <module>
#      18     predictions.append((a0.item(), a1.item()))
#      19     (obs_, downlink_msgs_), r, done = Task.step([a0.item(), a1.item()], [m0u_, m1u_])
# ---> 20     loss0, rew1 = agent0.train_on_batch([obs[0], downlink_msgs[0]], r[0], [obs_[0], downlink_msgs_[0]])
#      21     loss1, rew2 = agent1.train_on_batch([obs[1], downlink_msgs[1]], r[1], [obs_[1], downlink_msgs_[1]])
#      22     obs = obs_
#
# c:\Users\pizza\OneDrive\Documents\GitHub\Emergent-Communication-in-MARL\PredictionGame\agents\agent_AriaOnlineAC.py in train_on_batch(self, state, reward, state_)
#      92             _, _, _, value_ = self.forward(torch.tensor(state_[0]).float(), torch.tensor(state_[1]).float(), self.memories[1])
#      93         else:
# ---> 94             _, _, _, value_ = self.forward(torch.tensor(state_[0]).float(), torch.tensor(state_[1]).float(), None)
#      95
#      96         advantage = reward + self.gamma*value_.detach()-self.saved_values[0]
#
# c:\Users\pizza\OneDrive\Documents\GitHub\Emergent-Communication-in-MARL\PredictionGame\agents\agent_AriaOnlineAC.py in forward(self, obs, msg, memory)
#      53         action = self.action_Mod(hz)
#      54         message = self.msg_Dec(hz)
# ---> 55         value = self.value_head(hz)
#      56         return action, message, out_memory, value
#      57
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# c:\Users\pizza\OneDrive\Documents\GitHub\Emergent-Communication-in-MARL\PredictionGame\agents\agent_AriaOnlineAC.py in forward(self, x)
#     144         x_ = x
#     145         for m in self.mod:
# --> 146             x_ = m(x_)
#     147         return x_
#     148 class ariaActor(nn.Module):
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      92
#      93     def forward(self, input: Tensor) -> Tensor:
# ---> 94         return F.linear(input, self.weight, self.bias)
#      95
#      96     def extra_repr(self) -> str:
#
# ~\anaconda3\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1751     if has_torch_function_variadic(input, weight):
#    1752         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1753     return torch._C._nn.linear(input, weight, bias)
#    1754
#    1755
#
# ~\anaconda3\lib\traceback.py in format_stack(f, limit)
#     195     if f is None:
#     196         f = sys._getframe().f_back
# --> 197     return format_list(extract_stack(f, limit=limit))
#     198
#     199
#
# ~\anaconda3\lib\traceback.py in extract_stack(f, limit)
#     209     if f is None:
#     210         f = sys._getframe().f_back
# --> 211     stack = StackSummary.extract(walk_stack(f), limit=limit)
#     212     stack.reverse()
#     213     return stack
#
# ~\anaconda3\lib\traceback.py in extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     360                 filename, lineno, name, lookup_line=False, locals=f_locals))
#     361         for filename in fnames:
# --> 362             linecache.checkcache(filename)
#     363         # If immediate lookup was desired, trigger lookups now.
#     364         if lookup_lines:
#
# ~\anaconda3\lib\site-packages\IPython\core\compilerop.py in check_linecache_ipython(*args)
#     155     """
#     156     # First call the original checkcache as intended
# --> 157     linecache._checkcache_ori(*args)
#     158     # Then, update back the cache with our data, so that tracebacks related
#     159     # to our compiled codes can be produced.
#
# ~\anaconda3\lib\linecache.py in checkcache(filename)
#      72             continue   # no-op for files loaded via a __loader__
#      73         try:
# ---> 74             stat = os.stat(fullname)
#      75         except OSError:
#      76             cache.pop(filename, None)
#
# KeyboardInterrupt:
